# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # Условие 1: Задача 1
# - Постройте график
# - Назовите график
# - Сделайте именование оси x и оси y
# - Сделайте выводы

# %% [markdown]
# ### 1.1. Скачать следующие данные: kc-house-data

# %%
df = pd.read_csv('kc-house-data.csv')
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.sample(5)
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 17490  4331000190  20141223T000000  275000.0         3       1.00
# 8623   6303400395  20150130T000000  325000.0         1       0.75
# 20068  2883200524  20140512T000000  635000.0         3       2.50
# 12278  9578200030  20140728T000000  312000.0         3       2.00
# 1756   3295610350  20150323T000000  850000.0         5       2.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 17490         1290     11250     1.0           0     0  ...      7
# 8623           410      8636     1.0           0     0  ...      4
# 20068         1570      1433     3.0           0     0  ...      8
# 12278         2440     13250     1.0           0     0  ...      8
# 1756          3430     15119     2.0           0     0  ...     10
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 17490        1290              0      1956             0    98166  47.4743
# ...

# %% [markdown]
# Пустых ячеек нет, явные выбросы отсутствуют.

# %% [markdown]
# ### 1.2. Изучите стоимости недвижимости

# %%
plt.figure(figsize=(6,4))
sns.histplot(df['price'])
plt.xlabel('Стоимость недвижимости')
plt.ylabel('Количество');

# %% [markdown]
# Цена на дома находится в основном до 1 млн

# %% [markdown]
# ### 1.3. Изучите распределение квадратуры жилой

# %%
plt.figure(figsize=(6,4))
plt.hist(df['sqft_living'])
plt.xlabel('Жилая площадь')
plt.ylabel('Частота');

# %% [markdown]
# Большинство домов имеют жилую площадь до 3000 кв футов.

# %% [markdown]
# ### 1.4. Изучите распределение года постройки

# %%
plt.figure(figsize=(6,4))
plt.hist(df['yr_built'])
plt.ylabel('Частота')
plt.xlabel('Год постройки');

# %% [markdown]
# Наблюдается рост кол-ва построенных домов с 1950 года, вероятнее всего вследствие послевоенного демографического прироста.

# %% [markdown]
# ## 2 задача
# ### 2.1. Изучите распределение домов от наличия вида на набережную
# - Постройте график
# - Сделайте выводы

# %%
plt.pie(df['waterfront'].value_counts(), autopct="%1.1f%%", labels=('Нет' , 'Есть'))
plt.title("Дома с набережной");

# %% [markdown]
# Доля домов на набережной составляет всего 0.8%

# %% [markdown]
# ### 2.2. Изучите распределение этажей домов

# %%
plt.figure(figsize=(6,4))
plt.hist(df['floors'])
plt.ylabel('Частота')
plt.xlabel('Кол-во этажей');

# %% [markdown]
# В основном дома 1 или 2-х этажные. 1.5 домов значительно больше чем 2.5 домов, так как эта полоивна обычно обозначает жилой чердак, а такие часто задействованы в одноэтажных домах.

# %% [markdown]
# ### 2.3. Изучите распределение состояния домов

# %%
plt.figure(figsize=(6,4))
plt.hist(df['condition'])
plt.ylabel('Частота')
plt.xlabel('Состояние дома');

# %% [markdown]
# В основном дома в среднем состоянии.

# %% [markdown]
# ## 3 задача
# - Исследуйте, какие характеристики недвижимости влияют на стоимость недвижимости, с применением не менее 5 диаграмм из урока.
# - Анализ сделайте в формате storytelling: дополнить каждый график письменными выводами и наблюдениями.

# %% [markdown]
# Для начала нужно понять какие данные нас интересуют, в каких данных наиболее ярко выражена зависимость.

# %%
corrDf = df[['price', 'yr_built', 'yr_renovated', 'sqft_living', 'condition', 'grade', 'floors']].corr()
sns.heatmap(corrDf, annot=True, linewidths=1, cmap='coolwarm');

# %% [markdown]
# ### Сильно выраженная корреляция:
# - Цена дома к жилой площади
# - Цена дома к оценке дома
# - Жилая площадь к оценке дома
# ### Также корреляция выражена:
# - Год постройки к оценке и кол-ву этажей
# - Год постройки к жилой площади
# - Состояние к году постройки
# - Год постройки к году ренновации
# - Год постройки к состоянию
# - Кол-во этажей к состоянию

# %% [markdown]
# ## Отношение цены дома к величине жилой площади

# %% [markdown]
# На графике представлено соотношение цены и размера жилой площади. Цвет точек обозначает оценку дома, а крестики - дома у прибрежной линии.

# %%
sns.scatterplot(df, x='price', y='sqft_living', hue='grade', style='waterfront')
plt.xlabel("Цена (млн)")
plt.ylabel("Жилая площадь")
# Out:
# Text(0, 0.5, 'Жилая площадь')

# %% [markdown]
# Цена, ожидаемо, зависит от жилой площади. Но что интересно - разброс цены увеличивается с увеличением жилой площади, и, судя по цветовой гамме, увеличивается оценка дома. Возможно, размер жилой площади является одним из критериев выставления оценки дому.
#
# # Соотношение размера площади и оценки

# %%
plt.pie(df['grade'].value_counts(), labels=df["grade"].value_counts().index);

# %% [markdown]
# Большинство домов имеют оценку 7
# Рассмотрим такой же график у домов с видом на набережную

# %%
waterfrontHouses = df[df['waterfront'] == 1]
nonWaterfrontHouses = df[df['waterfront'] == 0]

# %%
plt.pie(waterfrontHouses['grade'].value_counts(), labels=waterfrontHouses["grade"].value_counts().index);

# %% [markdown]
# Оценка домов с видом на набережную выше, чем у домов в целом.

# %%
sns.lmplot(df, x='sqft_living', y='price', hue='waterfront')

# %% [markdown]
# На графике представлена динамика цен домов с видом на набережную и без него. Цена за квадратный фут домов на набережной выше чем у домов без вида на набережной. Небольшие дома стоят примерно столько же, но у домов больше 4000 квадратных футов разница более очевидна.

# %%
sns.lineplot(df, x='grade', y='sqft_living');

# %% [markdown]
# И оценка растет прямопропорционально размеру жилой площади, что доказывает что предположение о использовании размера жилой площади как параметра оценки верно.

# %% [markdown]
# # Соотношение площади и года постройки

# %%
sns.histplot(df, x='yr_built', y='sqft_living');

# %% [markdown]
# На графике виден всплеск с 1940 года, обусловлен ростом общего кол-ва домов показанном в пункте **1.4**

# %% [markdown]
# # Ухудшение состояния домов по годам

# %%
sns.lineplot(df, x='floors', y='condition')
# Out:
# <Axes: xlabel='floors', ylabel='condition'>

# %% [markdown]
# Добавим колонку с ценой за квадратный фут

# %%
df['price_per_sqft'] = df['price']/df['sqft_living']

# %%
sns.lineplot(df, x='floors', y='price_per_sqft');

# %% [markdown]
# С увеличением этажей слегка уменьшается состояние домов, возможно такие дома сложнее обслуживать, тем не менее цена за квадратный фут растет с количеством этажей.

# %% [markdown]
# # Вывод
#
# Разброс цен в предоставленных данных расширяется с увеличением жилой площади. Особенно это заметно по домам с видом на набережную.
# На оценку дома влияет прежде всего размер жилой площади, но наличие вида на набережную тоже играет важную роль
# Дома с большим количеством этажей стоят дороже, но сложнее в обслуживании.
